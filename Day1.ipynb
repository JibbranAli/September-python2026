# %%
print ("Hello ALL ")
# Out:
# Hello ALL

# %%
x = 5

# %%
print(x)
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
hello="Hello all"

# %%
print(hello)
# Out:
# Hello all

# %%
type(hello)
# Out:
# str

# %%
percentage=88.8

# %%
type(percentage)
# Out:
# float

# %%
present=True

# %%
type(present)
# Out:
# bool

# %%
# this is comment

# %%
"""

ashdajsdhas

adasdads

dasdsda

asdas

"""

print("HI")
# Out:
# HI

# %%
name = input ("Enter your name : ")
# Out:
# Enter your name :  Jibbran

# %%
print(name)
# Out:
# Jibbran

# %%
type(name)
# Out:
# str

# %%
mob = int(input("Enter your mobile number "))
# Out:
# Enter your mobile number  111111

# %%
type(mob)
# Out:
# int

# %%
mob = bool(input("Enter your mobile number "))
# Out:
# Enter your mobile number  True

# %%
type(mob)
# Out:
# bool

# %%
mob = float(input("Enter your mobile number "))
# Out:
# Enter your mobile number  3.14

# %%
type(mob)
# Out:
# float

# %%
name = input("Enter your name")

print("Your name is ", name, "I know that")

print(f"The name is {name} ")

# %%
name = int(input ("Enter your name : "))
# Out:
# Enter your name :  Tom
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 name = int(input ("Enter your name : "))
#
# ValueError: invalid literal for int() with base 10: 'Tom'
