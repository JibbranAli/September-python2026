# %%
a = 20
b = 10

# %%
print(a == b )
# Out:
# False

# %%
a > b
# Out:
# True

# %%
b > a
# Out:
# False

# %%
a < b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a != b
# Out:
# True

# %%
age  = 25 
salary = 50000

# %%
age >= 18 and salary >= 1000000
# Out:
# False

# %%
day = "sunday"

# %%
day == "monday" or day == "tuesday"
# Out:
# False

# %%
is_lodded_in = False

# %%
not is_lodded_in
# Out:
# True

# %%
username="root"

password = "redhat"

user = input("Enter user name : ")
passw = input ("Enter you password : ")


if username == user and password == passw :
    print("login DONE")
else:
    print("Invalid Credentiasl ")
# Out:
# Enter user name :  root
# Enter you password :  abc
# Invalid Credentiasl

# %%
## Assingment Operators

# %%
x = 10

# %%
x += 5
print(x)
# Out:
# 15

# %%
x -= 10

# %%
print(x)
# Out:
# 5

# %%
x *= 5

# %%
print(x)
# Out:
# 25

# %%
x /= 10

# %%
print(x)
# Out:
# 2.5

# %%
# Membership Operator

# %%
name = "python"

# %%
"p" in name
# Out:
# True

# %%
"x" in name
# Out:
# False

# %%
"x" not in  name
# Out:
# True

# %%
allowed_user = ["Tom", "Jack", "Pop"]

# %%
username = input ("Enter Username : ")

if username in allowed_user:
    print("Access Granted")
else:
    print("Access Denied ")
# Out:
# Enter Username :  Tom
# Access Granted

# %%
a = [10,20,30]

# %%
b = a

# %%
c = [10,20,30]

# %%
print(b)
# Out:
# [10, 20, 30]

# %%
a is b
# Out:
# True

# %%
id(a)
# Out:
# 2705850507648

# %%
id (b)
# Out:
# 2705850507648

# %%
id (c)
# Out:
# 2705850105408

# %%
a is b
# Out:
# True

# %%
a is c
# Out:
# False

# %%
import math

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.pow(2,5)
# Out:
# 32.0

# %%
math.factorial(5)
# Out:
# 120

# %%
import random

# %%
random.randint(1,10)
# Out:
# 4

# %%
print("--------------------------------")
print ("YOU VS COMPUTER ")
print("Choose any number between 1 to 10 ")
print("If you win YOU GET 3X amount ")
print("--------------------------------")
human = int (input ("Guess YOur NUmber : "))
computer = random.randint(1 , 10 )
print(f"Computer has choosen {computer} .... ")
if human == computer:
    print("Congratulation Human YOu won 3x amount ")

else:
  
    print("HA hA HA SOrry Human Comupter won ........")
# Out:
# --------------------------------
# YOU VS COMPUTER
# Choose any number between 1 to 10
# If you win YOU GET 3X amount
# --------------------------------
# Guess YOur NUmber :  4
# Computer has choosen 3 ....
# HA hA HA SOrry Human Comupter won ........

# %%
while True:
    print("--------------------------------")
    print ("YOU VS COMPUTER ")
    print("Choose any number between 1 to 10 ")
    print("If you win YOU GET 3X amount ")
    print("Enter 0 to exit ")
    print("--------------------------------")
    human = int(input ("Guess YOur NUmber : "))
    computer = random.randint(1 , 10 )
    if human == computer:
        print(f"Computer has choosen {computer} .... ")

        print("Congratulation Human YOu won 3x amount ")

    elif human == 0:
        break
    else:
        print(f"Computer has choosen {computer} .... ")

        print("HA hA HA SOrry Human Comupter won ........")
# Out:
# --------------------------------
# YOU VS COMPUTER
# Choose any number between 1 to 10
# If you win YOU GET 3X amount
# Enter 0 to exit
# --------------------------------
# Guess YOur NUmber :  3
# Computer has choosen 7 ....
# HA hA HA SOrry Human Comupter won ........
# --------------------------------
# YOU VS COMPUTER
# Choose any number between 1 to 10
# If you win YOU GET 3X amount
# Enter 0 to exit
# --------------------------------
# Guess YOur NUmber :  1
# Computer has choosen 8 ....
# HA hA HA SOrry Human Comupter won ........
# --------------------------------
# YOU VS COMPUTER
# Choose any number between 1 to 10
# If you win YOU GET 3X amount
# Enter 0 to exit
# --------------------------------
# Guess YOur NUmber :  9
# Computer has choosen 1 ....
# HA hA HA SOrry Human Comupter won ........
# --------------------------------
# YOU VS COMPUTER
# Choose any number between 1 to 10
# If you win YOU GET 3X amount
# Enter 0 to exit
# --------------------------------
# ...

# %%
import time

# %%
print(time.time())
# Out:
# 1790173961.8647976

# %%
time.sleep(3)

# %%
message = "Welcome to Python Program From Linux WORLD"

# %%
for character in message:
    print(character , end="", flush=True)
    time.sleep(0.1)

print("DONE")
# Out:
# Welcome to Python Program From Linux WORLDDONE
