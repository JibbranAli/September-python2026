# %% [markdown]
# ## LIST

# %%
student = ["Rahul","Amit", "JACk", "TOM"]

# %%
type(student)
# Out:
# list

# %%
data = ["Rahul", 22222222222, 86.30 , "Excellent", True]

# %%
print(data)
# Out:
# ['Rahul', 22222222222, 86.3, 'Excellent', True]

# %%
type(data)
# Out:
# list

# %%
student = ["Rahul","Amit", "JACk", "TOM"]

# %%
print(student[0])
# Out:
# Rahul

# %%
print(student[2])
# Out:
# JACk

# %%
print(student[8])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(student[8])
#
# IndexError: list index out of range

# %%
print(student[-4])
# Out:
# Rahul

# %%
print(student[-2])
# Out:
# JACk

# %%
print(student[-7])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(student[-7])
#
# IndexError: list index out of range

# %%
print(student[2])
# Out:
# JACk

# %%
print(student)
# Out:
# ['Rahul', 'Amit', 'JACk', 'TOM']

# %%
student[2] = "John"

# %%
print(student)
# Out:
# ['Rahul', 'Amit', 'John', 'TOM']

# %%
student.append("Nisha")

# %%
print(student)
# Out:
# ['Rahul', 'Amit', 'John', 'TOM', 'Nisha']

# %%
student.insert(1, "Misbah")

# %%
print(student)
# Out:
# ['Rahul', 'Misbah', 'Amit', 'John', 'TOM', 'Nisha']

# %%
student.remove("Amit")

# %%
print(student)
# Out:
# ['Rahul', 'Misbah', 'John', 'TOM', 'Nisha']

# %%
student.append("TOM")

# %%
print(student)
# Out:
# ['Rahul', 'Misbah', 'John', 'TOM', 'Nisha', 'TOM']

# %%
student.remove("TOM")

# %%
print(student)
# Out:
# ['Rahul', 'Misbah', 'John', 'Nisha', 'TOM']

# %%
student.pop()
# Out:
# 'TOM'

# %%
print(student)
# Out:
# ['Rahul', 'Misbah', 'John', 'Nisha']

# %%
student.count("Rahul")
# Out:
# 1

# %%
student.append("Rahul")

# %%
student.append("Rahul")

# %%
student.append("Rahul")

# %%
print(student)
# Out:
# ['Rahul', 'Misbah', 'John', 'Nisha', 'Rahul', 'Rahul', 'Rahul', 'Rahul']

# %%
student.count("Rahul")
# Out:
# 5

# %%
student.index("John")
# Out:
# 2

# %%
animal = ["tiger", "elephant", "lion", "monkey"]

# %%
name = input("Enter the name to search in animal list : ")
if name in animal:
    print("Animal Is present in list ")
else:
    print("Not Found")
# Out:
# Enter the name to search in animal list :  girraf
# Not Found

# %%
marks = [78, 48, 74,92, 67,88]

# %%
marks.sort()

# %%
print(marks)
# Out:
# [48, 67, 74, 78, 88, 92]

# %%
print(student)
# Out:
# ['Rahul', 'Misbah', 'John', 'Nisha', 'Rahul', 'Rahul', 'Rahul', 'Rahul']

# %%
student.sort()

# %%
print(student)
# Out:
# ['John', 'Misbah', 'Nisha', 'Rahul', 'Rahul', 'Rahul', 'Rahul', 'Rahul']

# %%
marks = [78, 48, 74,92, 67,88]

# %%
print("Marks:", marks)
print("Total Marks :", sum(marks))
print("Maximum Marks : ", max(marks))
print("Maximum Marks : ", min(marks))
print("Total Sujects : " , len(marks))
# Out:
# Marks: [78, 48, 74, 92, 67, 88]
# Total Marks : 447
# Maximum Marks :  92
# Maximum Marks :  48
# Total Sujects :  6

# %%
marks.reverse()

# %%
print(marks)
# Out:
# [88, 67, 92, 74, 48, 78]

# %%
alphabet = ["Z","X","C","B", "A"]

# %%
print(alphabet)
# Out:
# ['Z', 'X', 'C', 'B', 'A']

# %%
alphabet.sort()

# %%
print(alphabet)
# Out:
# ['A', 'B', 'C', 'X', 'Z']

# %%
alphabet.reverse()

# %%
print(alphabet)
# Out:
# ['Z', 'X', 'C', 'B', 'A']

# %% [markdown]
# ## TUPLE

# %%
co_ordinates = (18.52, 75.95)

# %%
type(co_ordinates)
# Out:
# tuple

# %%
co_ordinates.count(18.52)
# Out:
# 1

# %%
co_ordinates = (18.52, 75.95, 18.52, 75.95)

# %%
print(co_ordinates)
# Out:
# (18.52, 75.95, 18.52, 75.95)

# %%
co_ordinates.index(18.52)
# Out:
# 0

# %%
co_ordinates[1] = 111111
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 co_ordinates[1] = 111111
#
# TypeError: 'tuple' object does not support item assignment

# %%
co_ordinates.count(18.52)
# Out:
# 2

# %%
co_ordinates[1]
# Out:
# 75.95
